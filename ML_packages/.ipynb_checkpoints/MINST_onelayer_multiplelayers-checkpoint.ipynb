# %%
#Clasificación de imágenes del MINST usando una red de una capa y una red multicapas

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
#Tarea: Usar el conjunto de entrenamiento y validación MINTS para entrenar un modelo de una capa y una neurona usando la función activación 'softmax', una función de perdidad "sparse_categorical_crossentropy" y la metica 'accuracy'

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

print(np.shape(x_train))
print(np.shape(y_train))

print(np.shape(x_test))
print(np.shape(y_test))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %%
x_train=x_train/255
x_test=x_test/255

# %%
print(np.shape(x_train))
# Out:
# (60000, 28, 28)

# %%
x_train_flat = x_train.reshape(np.shape(x_train)[0],-1)
x_test_flat = x_test.reshape(np.shape(x_test)[0],-1)

np.shape(x_train)
np.shape(x_train_flat)
# Out:
# (60000, 784)

# %%
tf.keras.datasets.mnist.load_data?

# %%
ncols = 10
nrows = 10

fig, axs = plt.subplots(figsize = (20, 20))
plt.axis('off')

print('Imagenes de entrenamiento\n')

for i in range(ncols * nrows):

  axs = fig.add_subplot(nrows, ncols, i + 1)
  axs.imshow(x_train[i], cmap = 'Blues')
  axs.axis('off')

  label = 'Etiqueta: ' + str(y_train[i])
  plt.title(label)

plt.show()
# Out:
# Imagenes de entrenamiento

# %%
model = tf.keras.Sequential([
    #tf.keras.layers.Dense(units=1, activation='relu',input_shape=(784,)),
    tf.keras.layers.Dense(units = 10, activation = 'softmax',input_shape=(784,))])
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 10)             │         7,850 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,850 (30.66 KB)
#  Trainable params: 7,850 (30.66 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
tf.keras.utils.plot_model(model)

# %%
model.compile(
    loss = 'sparse_categorical_crossentropy', #loss function for multiple categories
    optimizer='sgd',#stochastic gradient descent
    metrics=['accuracy'] #accuracy
)

# %%
history = model.fit(
    x_train_flat,y_train,
    epochs=20,
    validation_data=(x_test_flat,y_test)
)
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9196 - loss: 0.2892 - val_accuracy: 0.9205 - val_loss: 0.2825
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9202 - loss: 0.2879 - val_accuracy: 0.9201 - val_loss: 0.2827
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9203 - loss: 0.2869 - val_accuracy: 0.9222 - val_loss: 0.2812
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9205 - loss: 0.2857 - val_accuracy: 0.9208 - val_loss: 0.2806
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9208 - loss: 0.2849 - val_accuracy: 0.9212 - val_loss: 0.2802
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9212 - loss: 0.2838 - val_accuracy: 0.9215 - val_loss: 0.2795
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9215 - loss: 0.2831 - val_accuracy: 0.9215 - val_loss: 0.2790
# Epoch 8/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9217 - loss: 0.2822 - val_accuracy: 0.9221 - val_loss: 0.2781
# Epoch 9/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9218 - loss: 0.2812 - val_accuracy: 0.9220 - val_loss: 0.2785
# Epoch 10/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9221 - loss: 0.2806 - val_accuracy: 0.9213 - val_loss: 0.2782
# Epoch 11/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9222 - loss: 0.2798 - val_accuracy: 0.9230 - val_loss: 0.2770
# Epoch 12/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9224 - loss: 0.2791 - val_accuracy: 0.9220 - val_loss: 0.2769
# Epoch 13/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9222 - loss: 0.2784 - val_accuracy: 0.9220 - val_loss: 0.2767
# Epoch 14/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9225 - loss: 0.2777 - val_accuracy: 0.9225 - val_loss: 0.2760
# Epoch 15/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9229 - loss: 0.2770 - val_accuracy: 0.9221 - val_loss: 0.2759
# Epoch 16/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9233 - loss: 0.2765 - val_accuracy: 0.9223 - val_loss: 0.2755
# Epoch 17/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9235 - loss: 0.2759 - val_accuracy: 0.9228 - val_loss: 0.2751
# Epoch 18/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9233 - loss: 0.2753 - val_accuracy: 0.9214 - val_loss: 0.2748
# Epoch 19/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9240 - loss: 0.2748 - val_accuracy: 0.9227 - val_loss: 0.2751
# Epoch 20/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9240 - loss: 0.2742 - val_accuracy: 0.9235 - val_loss: 0.2738

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']
ite_loss= np.arange(len(train_loss))

plt.plot(ite_loss,train_loss,label='training')
plt.plot(ite_loss,val_loss,label='Validation')
plt.legend()
plt.title("LOSS")
# Out:
# Text(0.5, 1.0, 'LOSS')

# %%
model_2 = tf.keras.Sequential([
    tf.keras.layers.Dense(units=1, activation='linear',input_shape=(784,)),
    tf.keras.layers.Dense(units = 10, activation = 'softmax')])
model_2.summary()

model_2.compile(
    loss = 'sparse_categorical_crossentropy', #loss function for multiple categories
    optimizer='sgd',#stochastic gradient descent
    metrics=['accuracy'] #accuracy
)
tf.keras.utils.plot_model(model_2)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 1)              │           785 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │            20 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 805 (3.14 KB)
#  Trainable params: 805 (3.14 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_2 = model_2.fit(
    x_train_flat,y_train,
    epochs=20,
    validation_data=(x_test_flat,y_test)
)
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3333 - loss: 1.7073 - val_accuracy: 0.3428 - val_loss: 1.6950
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3608 - loss: 1.6735 - val_accuracy: 0.3610 - val_loss: 1.6718
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3807 - loss: 1.6564 - val_accuracy: 0.3755 - val_loss: 1.6593
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3894 - loss: 1.6460 - val_accuracy: 0.3960 - val_loss: 1.6516
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3951 - loss: 1.6390 - val_accuracy: 0.3957 - val_loss: 1.6477
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.4015 - loss: 1.6341 - val_accuracy: 0.4029 - val_loss: 1.6449
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.4047 - loss: 1.6304 - val_accuracy: 0.3949 - val_loss: 1.6404
# Epoch 8/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.4048 - loss: 1.6276 - val_accuracy: 0.4077 - val_loss: 1.6419
# Epoch 9/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.4059 - loss: 1.6255 - val_accuracy: 0.3998 - val_loss: 1.6375
# Epoch 10/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.4078 - loss: 1.6238 - val_accuracy: 0.3956 - val_loss: 1.6358
# Epoch 11/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.4059 - loss: 1.6223 - val_accuracy: 0.4076 - val_loss: 1.6358
# Epoch 12/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.4063 - loss: 1.6211 - val_accuracy: 0.4018 - val_loss: 1.6330
# Epoch 13/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.4067 - loss: 1.6198 - val_accuracy: 0.3989 - val_loss: 1.6333
# Epoch 14/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.4040 - loss: 1.6187 - val_accuracy: 0.4000 - val_loss: 1.6331
# Epoch 15/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.4032 - loss: 1.6180 - val_accuracy: 0.4044 - val_loss: 1.6322
# Epoch 16/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.4048 - loss: 1.6169 - val_accuracy: 0.3919 - val_loss: 1.6316
# Epoch 17/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.4044 - loss: 1.6161 - val_accuracy: 0.4054 - val_loss: 1.6294
# Epoch 18/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.4030 - loss: 1.6153 - val_accuracy: 0.3961 - val_loss: 1.6303
# Epoch 19/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.4033 - loss: 1.6143 - val_accuracy: 0.3978 - val_loss: 1.6283
# Epoch 20/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.4011 - loss: 1.6132 - val_accuracy: 0.4040 - val_loss: 1.6273

# %%
model_3 = tf.keras.Sequential([
    tf.keras.layers.Dense(units=1, activation='relu',input_shape=(784,)),
    tf.keras.layers.Dense(units = 10, activation = 'softmax')])
model_3.summary()
model_3.compile(
    loss = 'sparse_categorical_crossentropy', #loss function for multiple categories
    optimizer='sgd',#stochastic gradient descent
    metrics=['accuracy'] #accuracy
)
tf.keras.utils.plot_model(model_3)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 1)              │           785 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 10)             │            20 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 805 (3.14 KB)
#  Trainable params: 805 (3.14 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_3 = model_3.fit(
    x_train_flat,y_train,
    epochs=50,
    validation_data=(x_test_flat,y_test)
)
# Out:
# Epoch 1/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3625 - loss: 1.6128 - val_accuracy: 0.3536 - val_loss: 1.6199
# Epoch 2/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3641 - loss: 1.6095 - val_accuracy: 0.3574 - val_loss: 1.6178
# Epoch 3/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3678 - loss: 1.6064 - val_accuracy: 0.3563 - val_loss: 1.6170
# Epoch 4/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3711 - loss: 1.6033 - val_accuracy: 0.3678 - val_loss: 1.6136
# Epoch 5/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3747 - loss: 1.6000 - val_accuracy: 0.3617 - val_loss: 1.6128
# Epoch 6/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3801 - loss: 1.5964 - val_accuracy: 0.3667 - val_loss: 1.6063
# Epoch 7/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3822 - loss: 1.5930 - val_accuracy: 0.3752 - val_loss: 1.6035
# Epoch 8/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.3858 - loss: 1.5891 - val_accuracy: 0.3871 - val_loss: 1.5980
# Epoch 9/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.3846 - loss: 1.5856 - val_accuracy: 0.3779 - val_loss: 1.5938
# Epoch 10/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3827 - loss: 1.5822 - val_accuracy: 0.3805 - val_loss: 1.5905
# Epoch 11/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3832 - loss: 1.5787 - val_accuracy: 0.3755 - val_loss: 1.5931
# Epoch 12/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3808 - loss: 1.5761 - val_accuracy: 0.3912 - val_loss: 1.5873
# Epoch 13/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3823 - loss: 1.5735 - val_accuracy: 0.3727 - val_loss: 1.5844
# Epoch 14/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3814 - loss: 1.5718 - val_accuracy: 0.3875 - val_loss: 1.5828
# Epoch 15/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3805 - loss: 1.5698 - val_accuracy: 0.3814 - val_loss: 1.5787
# Epoch 16/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3794 - loss: 1.5679 - val_accuracy: 0.3867 - val_loss: 1.5799
# Epoch 17/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.3795 - loss: 1.5667 - val_accuracy: 0.3785 - val_loss: 1.5757
# Epoch 18/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3762 - loss: 1.5652 - val_accuracy: 0.3773 - val_loss: 1.5770
# Epoch 19/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3786 - loss: 1.5637 - val_accuracy: 0.3711 - val_loss: 1.5803
# Epoch 20/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.3786 - loss: 1.5627 - val_accuracy: 0.3655 - val_loss: 1.5743
# Epoch 21/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3752 - loss: 1.5616 - val_accuracy: 0.3780 - val_loss: 1.5775
# Epoch 22/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3772 - loss: 1.5605 - val_accuracy: 0.3767 - val_loss: 1.5736
# Epoch 23/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3762 - loss: 1.5593 - val_accuracy: 0.3575 - val_loss: 1.5725
# Epoch 24/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3756 - loss: 1.5582 - val_accuracy: 0.3648 - val_loss: 1.5798
# Epoch 25/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3747 - loss: 1.5578 - val_accuracy: 0.3669 - val_loss: 1.5725
# Epoch 26/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.3709 - loss: 1.5567 - val_accuracy: 0.3701 - val_loss: 1.5693
# Epoch 27/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.3746 - loss: 1.5561 - val_accuracy: 0.3685 - val_loss: 1.5696
# Epoch 28/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.
100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3774 - loss: 1.5352 - val_accuracy: 0.3755 - val_loss: 1.5638
# Epoch 95/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3775 - loss: 1.5358 - val_accuracy: 0.3798 - val_loss: 1.5650
# Epoch 96/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3795 - loss: 1.5356 - val_accuracy: 0.3766 - val_loss: 1.5635
# Epoch 97/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3781 - loss: 1.5355 - val_accuracy: 0.3728 - val_loss: 1.5612
# Epoch 98/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3762 - loss: 1.5356 - val_accuracy: 0.3817 - val_loss: 1.5591
# Epoch 99/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.3761 - loss: 1.5357 - val_accuracy: 0.3726 - val_loss: 1.5625
# Epoch 100/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3778 - loss: 1.5353 - val_accuracy: 0.3763 - val_loss: 1.5640

# %%
train_loss = history_3.history['loss']
val_loss = history_3.history['val_loss']
ite_loss= np.arange(len(train_loss))

plt.plot(ite_loss,train_loss,label='training')
plt.plot(ite_loss,val_loss,label='Validation')
plt.legend()
plt.title("LOSS")
plt.ylim(-1,10)
# Out:
# (-1.0, 10.0)

# %%
model_5 = tf.keras.Sequential([
    tf.keras.layers.Dense(units=512, activation='relu',input_shape=(784,)),
    tf.keras.layers.Dense(units=512, activation='relu'),
    tf.keras.layers.Dense(units = 10, activation = 'softmax')])
model_5.summary()
model_5.compile(
    loss = 'sparse_categorical_crossentropy', #loss function for multiple categories
    optimizer='sgd',#stochastic gradient descent
    metrics=['accuracy'] #accuracy
)
tf.keras.utils.plot_model(model_5)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_5 (Dense)                 │ (None, 512)            │       401,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 669,706 (2.55 MB)
#  Trainable params: 669,706 (2.55 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_5 = model_5.fit(
    x_train_flat,y_train,
    batch_size =128,
    epochs=50,
    validation_data=(x_test_flat,y_test)
)
# Out:
# Epoch 1/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.7614 - loss: 1.0968 - val_accuracy: 0.8808 - val_loss: 0.5140
# Epoch 2/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8846 - loss: 0.4479 - val_accuracy: 0.9035 - val_loss: 0.3646
# Epoch 3/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9021 - loss: 0.3581 - val_accuracy: 0.9144 - val_loss: 0.3159
# Epoch 4/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9118 - loss: 0.3179 - val_accuracy: 0.9200 - val_loss: 0.2879
# Epoch 5/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9183 - loss: 0.2919 - val_accuracy: 0.9278 - val_loss: 0.2659
# Epoch 6/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9239 - loss: 0.2724 - val_accuracy: 0.9311 - val_loss: 0.2526
# Epoch 7/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9282 - loss: 0.2564 - val_accuracy: 0.9358 - val_loss: 0.2382
# Epoch 8/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9319 - loss: 0.2425 - val_accuracy: 0.9372 - val_loss: 0.2274
# Epoch 9/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9357 - loss: 0.2303 - val_accuracy: 0.9385 - val_loss: 0.2180
# Epoch 10/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9385 - loss: 0.2196 - val_accuracy: 0.9414 - val_loss: 0.2079
# Epoch 11/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9414 - loss: 0.2097 - val_accuracy: 0.9435 - val_loss: 0.2011
# Epoch 12/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9434 - loss: 0.2008 - val_accuracy: 0.9463 - val_loss: 0.1930
# Epoch 13/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9457 - loss: 0.1925 - val_accuracy: 0.9472 - val_loss: 0.1863
# Epoch 14/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9479 - loss: 0.1850 - val_accuracy: 0.9489 - val_loss: 0.1792
# Epoch 15/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9498 - loss: 0.1781 - val_accuracy: 0.9503 - val_loss: 0.1735
# Epoch 16/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9521 - loss: 0.1712 - val_accuracy: 0.9524 - val_loss: 0.1695
# Epoch 17/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.
50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9818 - loss: 0.0687 - val_accuracy: 0.9727 - val_loss: 0.0869

# %%
train_loss = history_5.history['loss']
val_loss = history_5.history['val_loss']
ite_loss= np.arange(len(train_loss))

plt.plot(ite_loss,train_loss,label='training')
plt.plot(ite_loss,val_loss,label='Validation')
plt.legend()
plt.title("LOSS")
plt.xlim(0,5)
# Out:
# (0.0, 5.0)

# %%
print(np.shape(x_train),np.shape(x_test))
x_train=x_train.reshape(-1,28,28,1)
x_test=x_test.reshape(-1,28,28,1)
print(np.shape(x_train),np.shape(x_test))
# Out:
# (60000, 28, 28) (10000, 28, 28)
# (60000, 28, 28, 1) (10000, 28, 28, 1)

# %%
modelConv_1 = tf.keras.Sequential([
    tf.keras.layers.Conv2D(filters=16,kernel_size=(3,3),strides=(2,2),padding='valid',input_shape=(28,28,1)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=512, activation='relu'),
    tf.keras.layers.Dense(units = 10, activation = 'softmax')])
modelConv_1.summary()
modelConv_1.compile(
    loss = 'sparse_categorical_crossentropy', #loss function for multiple categories
    optimizer='sgd',#stochastic gradient descent
    metrics=['accuracy'] #accuracy
)
tf.keras.utils.plot_model(modelConv_1)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 13, 13, 16)     │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 2704)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 512)            │     1,384,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,390,250 (5.30 MB)
#  Trainable params: 1,390,250 (5.30 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.shape(x_test)
# Out:
# (10000, 28, 28, 1)

# %%
history_conv1 = modelConv_1 .fit(
    x_train,y_train,
    batch_size =128,
    epochs=20,
    validation_data=(x_test,y_test)
)
# Out:
# Epoch 1/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - accuracy: 0.9896 - loss: 0.0397 - val_accuracy: 0.9803 - val_loss: 0.0626
# Epoch 2/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 14s 30ms/step - accuracy: 0.9895 - loss: 0.0391 - val_accuracy: 0.9791 - val_loss: 0.0668
# Epoch 3/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - accuracy: 0.9899 - loss: 0.0380 - val_accuracy: 0.9799 - val_loss: 0.0637
# Epoch 4/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - accuracy: 0.9906 - loss: 0.0368 - val_accuracy: 0.9800 - val_loss: 0.0625
# Epoch 5/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step - accuracy: 0.9895 - loss: 0.0377 - val_accuracy: 0.9817 - val_loss: 0.0604
# Epoch 6/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - accuracy: 0.9916 - loss: 0.0353 - val_accuracy: 0.9809 - val_loss: 0.0606
# Epoch 7/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.9903 - loss: 0.0351 - val_accuracy: 0.9813 - val_loss: 0.0605
# Epoch 8/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - accuracy: 0.9910 - loss: 0.0342 - val_accuracy: 0.9815 - val_loss: 0.0599
# Epoch 9/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.9918 - loss: 0.0320 - val_accuracy: 0.9811 - val_loss: 0.0599
# Epoch 10/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - accuracy: 0.9920 - loss: 0.0316 - val_accuracy: 0.9807 - val_loss: 0.0601
# Epoch 11/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - accuracy: 0.9917 - loss: 0.0307 - val_accuracy: 0.9814 - val_loss: 0.0603
# Epoch 12/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.9920 - loss: 0.0314 - val_accuracy: 0.9803 - val_loss: 0.0601
# Epoch 13/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.9916 - loss: 0.0311 - val_accuracy: 0.9817 - val_loss: 0.0581
# Epoch 14/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 18s 28ms/step - accuracy: 0.9926 - loss: 0.0291 - val_accuracy: 0.9822 - val_loss: 0.0578
# Epoch 15/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 14s 29ms/step - accuracy: 0.9933 - loss: 0.0278 - val_accuracy: 0.9807 - val_loss: 0.0598
# Epoch 16/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - accuracy: 0.9937 - loss: 0.0273 - val_accuracy: 0.9820 - val_loss: 0.0573
# Epoch 17/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - accuracy: 0.9942 - loss: 0.0258 - val_accuracy: 0.9814 - val_loss: 0.0581
# Epoch 18/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 14s 30ms/step - accuracy: 0.9937 - loss: 0.0261 - val_accuracy: 0.9817 - val_loss: 0.0578
# Epoch 19/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - accuracy: 0.9937 - loss: 0.0258 - val_accuracy: 0.9824 - val_loss: 0.0563
# Epoch 20/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - accuracy: 0.9941 - loss: 0.0256 - val_accuracy: 0.9816 - val_loss: 0.0573

# %%
train_loss = history_conv1.history['loss']
val_loss = history_conv1.history['val_loss']
ite_loss= np.arange(len(train_loss))

plt.plot(ite_loss,train_loss,label='training')
plt.plot(ite_loss,val_loss,label='Validation')
plt.legend()
plt.title("LOSS")
# Out:
# Text(0.5, 1.0, 'LOSS')

# %%
modelConv_2 = tf.keras.Sequential([
    tf.keras.layers.Conv2D(filters=16,kernel_size=(3,3),strides=(2,2),padding='valid',input_shape=(28,28,1)),
    tf.keras.layers.MaxPool2D(pool_size= (2,2)),
    tf.keras.layers.Conv2D(filters=32,kernel_size=(3,3),strides=(2,2),padding='valid',activation='relu'),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=512, activation='relu'),
    tf.keras.layers.Dense(units = 10, activation = 'softmax')])
modelConv_2.summary()
modelConv_2.compile(
    loss = 'sparse_categorical_crossentropy', #loss function for multiple categories
    optimizer='sgd',#stochastic gradient descent
    metrics=['accuracy'] #accuracy
)
tf.keras.utils.plot_model(modelConv_2)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_9 (Conv2D)               │ (None, 13, 13, 16)     │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 2, 2, 32)       │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 512)            │        66,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 75,978 (296.79 KB)
#  Trainable params: 75,978 (296.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_conv2 = modelConv_2 .fit(
    x_train,y_train,
    batch_size =128,
    epochs=10,
    validation_data=(x_test,y_test)
)
# Out:
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9181 - loss: 0.2718 - val_accuracy: 0.9272 - val_loss: 0.2389
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9246 - loss: 0.2523 - val_accuracy: 0.9314 - val_loss: 0.2247
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9300 - loss: 0.2318 - val_accuracy: 0.9370 - val_loss: 0.2109
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9340 - loss: 0.2187 - val_accuracy: 0.9401 - val_loss: 0.1980
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9361 - loss: 0.2136 - val_accuracy: 0.9424 - val_loss: 0.1878
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9422 - loss: 0.1921 - val_accuracy: 0.9442 - val_loss: 0.1784
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9443 - loss: 0.1877 - val_accuracy: 0.9475 - val_loss: 0.1740
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9473 - loss: 0.1755 - val_accuracy: 0.9489 - val_loss: 0.1666
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9484 - loss: 0.1713 - val_accuracy: 0.9547 - val_loss: 0.1571
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9488 - loss: 0.1685 - val_accuracy: 0.9538 - val_loss: 0.1547

# %%
train_loss = history_conv2.history['loss']
val_loss = history_conv2.history['val_loss']
ite_loss= np.arange(len(train_loss))

plt.plot(ite_loss,train_loss,label='training')
plt.plot(ite_loss,val_loss,label='Validation')
plt.legend()
plt.title("LOSS")
# Out:
# Text(0.5, 1.0, 'LOSS')
