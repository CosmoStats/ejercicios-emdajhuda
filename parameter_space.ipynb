# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Creamos una distribución lineal de dos parametros x, y
r = np.linspace(-1,1,21)
theta = np.linspace(-1,1,21)

R, Theta = np.meshgrid(x, y)

# %%
X_p = R * np.cos(Theta)
Y_p = R * np.sin(Theta)

# %%
plt.scatter(R, Theta, color='blue')
plt.scatter(X_p, Y_p, color='red')
plt.show()
